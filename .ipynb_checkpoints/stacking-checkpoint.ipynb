# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = sns.load_dataset("iris")
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
X = df.drop("species", axis=1)
y= df["species"]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)

# %%
from sklearn.svm import SVC

# %%
model_SVM = SVC(C=12, kernel="rbf", gamma="scale")

# %%
model_SVM.fit(X_train,y_train)
# Out:
# SVC(C=12)

# %%
model_SVM.score(X_test,y_test)
# Out:
# 1.0

# %%
from sklearn.model_selection import GridSearchCV

# %%
classifier = GridSearchCV((model_SVM),{
    "C":[1,3,5,10,20,25,30],
    "kernel":["rbf","linear","poly"],
    "gamma":["scale", "auto"]
},cv=5,return_train_score=False)

# %%
classifier.fit(X,y)
# Out:
# GridSearchCV(cv=5, estimator=SVC(C=20, kernel='linear'),
#              param_grid={'C': [1, 3, 5, 10, 20, 25, 30],
#                          'gamma': ['scale', 'auto'],
#                          'kernel': ['rbf', 'linear', 'poly']})

# %%
results = pd.DataFrame(classifier.cv_results_)
results
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  param_C  \
# 0        0.004484      0.001090         0.003237        0.001082        1
# 1        0.002483      0.000263         0.001709        0.000132        1
# 2        0.002634      0.000770         0.001582        0.000033        1
# 3        0.002247      0.000047         0.001663        0.000047        1
# 4        0.002081      0.000018         0.001538        0.000005        1
# 5        0.003171      0.001086         0.001557        0.000027        1
# 6        0.002394      0.000201         0.001659        0.000021        3
# 7        0.002163      0.000075         0.001540        0.000012        3
# 8        0.002476      0.000392         0.001865        0.000457        3
# 9        0.002371      0.000163         0.001684        0.000030        3
# 10       0.002107      0.000038         0.001557        0.000028        3
# 11       0.003798      0.001810         0.001581        0.000090        3
# 12       0.002194      0.000017         0.001615        0.000007        5
# 13       0.002264      0.000188         0.001617        0.000098        5
# 14       0.002218      0.000057         0.001678        0.000122        5
# 15       0.002271      0.000064         0.001665        0.000026        5
# 16       0.002238      0.000161         0.001659        0.000148        5
# 17       0.004356      0.001851         0.001563        0.000026        5
# 18       0.002232      0.000141         0.001600        0.000015       10
# 19       0.002127      0.000024         0.001556        0.000031       10
# 20       0.002594      0.000698         0.001900        0.000481       10
# 21       0.002276      0.000187         0.001646        0.000068       10
# 22       0.002196      0.000142         0.001654        0.000120       10
# 23       0.004950      0.002377         0.001581        0.000059       10
# 24       0.002297      0.000112         0.001759        0.000173       20
# 25       0.002736      0.000827         0.002267        0.000748       20
# 26       0.002958      0.000576         0.001723        0.000122       20
# 27       0.002524      0.000223         0.002043        0.000345       20
# 28       0.002482      0.000214         0.001864        0.000204       20
# 29       0.009443      0.006583         0.002096        0.000209       20
# 30       0.002791      0.000522         0.001704        0.000037       25
# 31       0.002463      0.000209         0.001775        0.000218       25
# 32       0.002396      0.000097         0.001596        0.000030       25
# 33       0.002194      0.000036         0.001630        0.000028       25
# 34       0.002120      0.000031         0.001545        0.000010       25
# 35       0.010670      0.009670         0.001607        0.000036       25
# 36       0.002344      0.000134         0.001626        0.000038       30
# 37       0.002442      0.000196         0.002151        0.000457       30
# 38       0.002889      0.000433         0.001972        0.000239       30
# 39       0.002863      0.000390         0.001960        0.000323       30
# 40       0.002619      0.000309         0.001723        0.000134       30
# 41       0.009972      0.006069         0.002052        0.000321       30
#
#    param_gamma param_kernel                                           params  \
# 0        scale          rbf      {'C': 1, 'gamma': 'scale', 'kernel': 'rbf'}
# 1        scale       linear   {'C': 1, 'gamma': 'scale', 'kernel': 'linear'}
# 2        scale         poly     {'C': 1, 'gamma': 'scale', 'kernel': 'poly'}
# 3         auto          rbf       {'C': 1, 'gamma': 'auto', 'kernel': 'rbf'}
# 4         auto       linear    {'C': 1, 'gamma': 'auto', 'kernel': 'linear'}
# 5         auto         poly      {'C': 1, 'gamma': 'auto', 'kernel': 'poly'}
# 6        scale          rbf      {'C': 3, 'gamma': 'scale', 'kernel': 'rbf'}
# 7        scale       linear   {'C': 3, 'gamma': 'scale', 'kernel': 'linear'}
# 8        scale         poly     {'C': 3, 'gamma': 'scale', 'kernel': 'poly'}
# 9         auto          rbf       {'C': 3, 'gamma': 'auto', 'kernel': 'rbf'}
# 10        auto       linear    {'C': 3, 'gamma': 'auto', 'kernel': 'linear'}
# 11        auto         poly      {'C': 3, 'gamma': 'auto', 'kernel': 'poly'}
# 12       scale          rbf      {'C': 5, 'gamma': 'scale', 'kernel': 'rbf'}
# 13       scale       linear   {'C': 5, 'gamma': 'scale', 'kernel': 'linear'}
# 14       scale         poly     {'C': 5, 'gamma': 'scale', 'kernel': 'poly'}
# 15        auto          rbf       {'C': 5, 'gamma': 'auto', 'kernel': 'rbf'}
# 16        auto       linear    {'C': 5, 'gamma': 'auto', 'kernel': 'linear'}
# 17        auto         poly      {'C': 5, 'gamma': 'auto', 'kernel': 'poly'}
# 18       scale          rbf     {'C': 10, 'gamma': 'scale', 'kernel': 'rbf'}
# 19       scale       linear  {'C': 10, 'gamma': 'scale', 'kernel': 'linear'}
# 20       scale         poly    {'C': 10, 'gamma': 'scale', 'kernel': 'poly'}
# 21        auto          rbf      {'C': 10, 'gamma': 'auto', 'kernel': 'rbf'}
# 22        auto       linear   {'C': 10, 'gamma': 'auto', 'kernel': 'linear'}
# 23        auto         poly     {'C': 10, 'gamma': 'auto', 'kernel': 'poly'}
# 24       scale          rbf     {'C': 20, 'gamma': 'scale', 'kernel': 'rbf'}
# 25       scale       linear  {'C': 20, 'gamma': 'scale', 'kernel': 'linear'}
# 26       scale         poly    {'C': 20, 'gamma': 'scale', 'kernel': 'poly'}
# 27        auto          rbf      {'C': 20, 'gamma': 'auto', 'kernel': 'rbf'}
# 28        auto       linear   {'C': 20, 'gamma': 'auto', 'kernel': 'linear'}
# 29        auto         poly     {'C': 20, 'gamma': 'auto', 'kernel': 'poly'}
# 30       scale          rbf     {'C': 25, 'gamma': 'scale', 'kernel': 'rbf'}
# 31       scale       linear  {'C': 25, 'gamma': 'scale', 'kernel': 'linear'}
# 32       scale         poly    {'C': 25, 'gamma': 'scale', 'kernel': 'poly'}
# 33        auto          rbf      {'C': 25, 'gamma': 'auto', 'kernel': 'rbf'}
# 34        auto       linear   {'C': 25, 'gamma': 'auto', 'kernel': 'linear'}
# 35        auto         poly     {'C': 25, 'gamma': 'auto', 'kernel': 'poly'}
# 36       scale          rbf     {'C': 30, 'gamma': 'scale', 'kernel': 'rbf'}
# 37       scale       linear  {'C': 30, 'gamma': 'scale', 'kernel': 'linear'}
# 38       scale         poly    {'C': 30, 'gamma': 'scale', 'kernel': 'poly'}
# 39        auto          rbf      {'C': 30, 'gamma': 'auto', 'kernel': 'rbf'}
# 40        auto       linear   {'C': 30, 'gamma': 'auto', 'kernel': 'linear'}
# 41        auto         poly     {'C': 30, 'gamma': 'auto', 'kernel': 'poly'}
#
#     split0_test_score  split1_test_score  split2_test_score  \
# 0            0.966667           0.966667           0.966667
# 1            0.966667           1.000000           0.966667
# 2            0.966667           1.000000           0.966667
# 3            0.966667           1.000000           0.966667
# 4            0.966667           1.000000           0.966667
# 5            1.000000           1.000000           0.900000
# 6            0.966667           1.000000           0.966667
# 7            0.966667           1.000000           0.933333
# 8            1.000000           1.000000           0.900000
# 9            0.966667           1.000000           0.933333
# 10           0.966667           1.000000           0.933333
# 11           1.000000           1.000000           0.900000
# 12           0.966667           1.000000           1.000000
# 13           1.000000           1.000000           0.933333
# 14           1.000000           1.000000           0.900000
# 15           0.966667           1.000000           0.966667
# 16           1.000000           1.000000           0.933333
# 17           1.000000           1.000000           0.900000
# 18           0.966667           1.000000           0.966667
# 19           1.000000           1.000000           0.900000
# 20           1.000000           1.000000           0.900000
# 21           0.966667           1.000000           0.966667
# 22           1.000000           1.000000           0.900000
# 23           1.000000           1.000000           0.900000
# 24           0.966667           1.000000           0.966667
# 25           1.000000           1.000000           0.900000
# 26           1.000000           1.000000           0.900000
# 27           0.966667           1.000000           0.900000
# 28           1.000000           1.000000           0.900000
# 29           0.966667           0.966667           0.900000
# 30           0.966667           1.000000           0.966667
# 31           1.000000           1.000000           0.900000
# 32           1.000000           1.000000           0.900000
# 33           0.966667           1.000000           0.900000
# 34           1.000000           1.000000           0.900000
# 35           0.966667           0.966667           0.900000
# 36           0.966667           1.000000           0.933333
# 37           1.000000           1.000000           0.900000
# 38           1.000000           1.000000           0.900000
# 39           0.966667           1.000000           0.900000
# 40           1.000000           1.000000           0.900000
# 41           0.966667           0.966667           0.900000
#
#     split3_test_score  split4_test_score  mean_test_score  std_test_score  \
# 0            0.933333                1.0         0.966667        0.021082
# 1            0.966667                1.0         0.980000        0.016330
# 2            0.966667                1.0         0.980000        0.016330
# 3            0.966667                1.0         0.980000        0.016330
# 4            0.966667                1.0         0.980000        0.016330
# 5            0.933333                1.0         0.966667        0.042164
# 6            0.966667                1.0         0.980000        0.016330
# 7            0.966667                1.0         0.973333        0.024944
# 8            0.933333                1.0         0.966667        0.042164
# 9            0.966667                1.0         0.973333        0.024944
# 10           0.966667                1.0         0.973333        0.024944
# 11           0.933333                1.0         0.966667        0.042164
# 12           0.966667                1.0         0.986667        0.016330
# 13           0.966667                1.0         0.980000        0.026667
# 14           0.933333                1.0         0.966667        0.042164
# 15           0.966667                1.0         0.980000        0.016330
# 16           0.966667                1.0         0.980000        0.026667
# 17           0.933333                1.0         0.966667        0.042164
# 18           0.966667                1.0         0.980000        0.016330
# 19           0.966667                1.0         0.973333        0.038873
# 20           0.933333                1.0         0.966667        0.042164
# 21           0.966667                1.0         0.980000        0.016330
# 22           0.966667                1.0         0.973333        0.038873
# 23           0.933333                1.0         0.966667        0.042164
# 24           0.966667                1.0         0.980000        0.016330
# 25           0.933333                1.0         0.966667        0.042164
# 26           0.933333                1.0         0.966667        0.042164
# 27           0.966667                1.0         0.966667        0.036515
# 28           0.933333                1.0         0.966667        0.042164
# 29           0.933333                1.0         0.953333        0.033993
# 30           0.966667                1.0         0.980000        0.016330
# 31           0.900000                1.0         0.960000        0.048990
# 32           0.933333                1.0         0.966667        0.042164
# 33           0.966667                1.0         0.966667        0.036515
# 34           0.900000                1.0         0.960000        0.048990
# 35           0.933333                1.0         0.953333        0.033993
# 36           0.966667                1.0         0.973333        0.024944
# 37           0.900000                1.0         0.960000        0.048990
# 38           0.933333                1.0         0.966667        0.042164
# 39           0.933333                1.0         0.960000        0.038873
# 40           0.900000                1.0         0.960000        0.048990
# 41           0.933333                1.0         0.953333        0.033993
#
#     rank_test_score
# 0                22
# 1                 2
# 2                 2
# 3                 2
# 4                 2
# 5                22
# 6                 2
# 7                14
# 8                22
# 9                14
# 10               14
# 11               22
# 12                1
# 13                2
# 14               22
# 15                2
# 16                2
# 17               22
# 18                2
# 19               14
# 20               22
# 21                2
# 22               14
# 23               22
# 24                2
# 25               22
# 26               22
# 27               20
# 28               22
# 29               40
# 30                2
# 31               35
# 32               22
# 33               20
# 34               35
# 35               40
# 36               14
# 37               35
# 38               22
# 39               35
# 40               35
# 41               40

# %%
final_results = results[["param_C","param_gamma","param_kernel","mean_test_score"]]
final_results
# Out:
#     param_C param_gamma param_kernel  mean_test_score
# 0         1       scale          rbf         0.966667
# 1         1       scale       linear         0.980000
# 2         1       scale         poly         0.980000
# 3         1        auto          rbf         0.980000
# 4         1        auto       linear         0.980000
# 5         1        auto         poly         0.966667
# 6         3       scale          rbf         0.980000
# 7         3       scale       linear         0.973333
# 8         3       scale         poly         0.966667
# 9         3        auto          rbf         0.973333
# 10        3        auto       linear         0.973333
# 11        3        auto         poly         0.966667
# 12        5       scale          rbf         0.986667
# 13        5       scale       linear         0.980000
# 14        5       scale         poly         0.966667
# 15        5        auto          rbf         0.980000
# 16        5        auto       linear         0.980000
# 17        5        auto         poly         0.966667
# 18       10       scale          rbf         0.980000
# 19       10       scale       linear         0.973333
# 20       10       scale         poly         0.966667
# 21       10        auto          rbf         0.980000
# 22       10        auto       linear         0.973333
# 23       10        auto         poly         0.966667
# 24       20       scale          rbf         0.980000
# 25       20       scale       linear         0.966667
# 26       20       scale         poly         0.966667
# 27       20        auto          rbf         0.966667
# 28       20        auto       linear         0.966667
# 29       20        auto         poly         0.953333
# 30       25       scale          rbf         0.980000
# 31       25       scale       linear         0.960000
# 32       25       scale         poly         0.966667
# 33       25        auto          rbf         0.966667
# 34       25        auto       linear         0.960000
# 35       25        auto         poly         0.953333
# 36       30       scale          rbf         0.973333
# 37       30       scale       linear         0.960000
# 38       30       scale         poly         0.966667
# 39       30        auto          rbf         0.960000
# 40       30        auto       linear         0.960000
# 41       30        auto         poly         0.953333

# %%
final_results[final_results["mean_test_score"] == final_results["mean_test_score"].max()]
# Out:
#     param_C param_gamma param_kernel  mean_test_score
# 12        5       scale          rbf         0.986667
